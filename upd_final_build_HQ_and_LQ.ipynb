# %%
# import packages
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import plotly.express as px
import numpy as np

# %% [markdown]
# ### Source of info
#
# - **results/HQcl_representative_MAGs_all_info.xlsx** - Representative genomes from HQ clustering. Created with Final_build_HQcl.ipynb (1,641 lines)
# - **results/LQcl_representative_MAGs_all_info.xlsx** - Representative genomes from LQ clustering. Created with Final_build_LQcl.ipynb (5 lines)
# - **results/HQLQcl_together_Cdb.csv** - info about secondary_cluster. Created with dREP (9,475 lines, only bins goin to clustering)
#
# - **input/HQLQcl_representative_genomes_list.csv** - list of representatives genomes from cluster. Created with 'ls * all dereplicated

# %%
## Step 1. Combine HQ and LQ representative genomes
# Combine HQcl_representative_MAGs_all_info.xlsx an LQcl_representative_MAGs_all_info.xlsx
HQcl = pd.read_excel('results/HQcl_representative_MAGs_all_info.xlsx')
LQcl = pd.read_excel('results/LQcl_representative_MAGs_all_info.xlsx')
# Combine HQcl and LQcl
HQcl_LQcl = pd.concat([HQcl, LQcl])
# reset index
HQcl_LQcl = HQcl_LQcl.reset_index(drop=True)
HQcl_LQcl.tail(2)
# Out:
#                    rep_MAG_name pre_cluster  completeness  contamination  \
# 3899       VPOVJ1_maxbin.023.fa         NaN         90.02          40.44
# 3900  VXL3GC_vamb.168970_sub.fa         NaN         65.52          12.07
#
#       strain_heterogeneity   length     N50 bst_preCl_bin_name   cluster  \
# 3899                   2.7  4085276    1811                NaN  LQ-112_1
# 3900                   0.0  1579696  108092                NaN  LQ-385_2
#
#         domain           phylum             class                order  \
# 3899  Bacteria  Cyanobacteriota  Vampirovibrionia  Gastranaerophilales
# 3900  Bacteria  Cyanobacteriota  Vampirovibrionia  Gastranaerophilales
#
#                     family   genus         sp  bin_number_in_cluster bin_qual  \
# 3899  Gastranaerophilaceae  Zag111  undefined                      1       LQ
# 3900  Gastranaerophilaceae  Zag111  undefined                      1       LQ
#
#                 rep_MAG_ID
# 3899  L1416_Zag111_undS.fa
# 3900  L1588_Zag111_undS.fa

# %%
## Step 1. Add info about cluster
cluster = pd.read_csv('input/HQLQcl_together_Cdb.csv')
# rename column genome
cluster = cluster.rename(columns={'genome': 'rep_MAG_ID'})
# keep only bin name and cluster columns
cluster = cluster[['rep_MAG_ID', 'secondary_cluster']]
cluster = cluster.rename(columns={'secondary_cluster': 'HQLQ_cluster'})
cluster.tail(2)

# merge HQcl_LQcl and cluster
mrg_st1 = pd.merge(HQcl_LQcl, cluster, on='rep_MAG_ID', how='outer')
mrg_st1.tail(2)
# Out:
#                    rep_MAG_name pre_cluster  completeness  contamination  \
# 3899       VPOVJ1_maxbin.023.fa         NaN         90.02          40.44
# 3900  VXL3GC_vamb.168970_sub.fa         NaN         65.52          12.07
#
#       strain_heterogeneity   length     N50 bst_preCl_bin_name   cluster  \
# 3899                   2.7  4085276    1811                NaN  LQ-112_1
# 3900                   0.0  1579696  108092                NaN  LQ-385_2
#
#         domain           phylum             class                order  \
# 3899  Bacteria  Cyanobacteriota  Vampirovibrionia  Gastranaerophilales
# 3900  Bacteria  Cyanobacteriota  Vampirovibrionia  Gastranaerophilales
#
#                     family   genus         sp  bin_number_in_cluster bin_qual  \
# 3899  Gastranaerophilaceae  Zag111  undefined                      1       LQ
# 3900  Gastranaerophilaceae  Zag111  undefined                      1       LQ
#
#                 rep_MAG_ID HQLQ_cluster
# 3899  L1416_Zag111_undS.fa        162_1
# 3900  L1588_Zag111_undS.fa        154_1

# %%
# Step 2. Read the list of representative genomes from HQLQ clustering
lst = pd.read_csv('input/HQLQcl_representative_genomes_list.csv')
lst.tail(2)

# define cluster for HQLQ_rep_MAGs
mrg_st2 = pd.merge(lst, mrg_st1, left_on='HQLQ_rep_MAG_ID', right_on='rep_MAG_ID', how='inner')
mrg_st2 = mrg_st2[['HQLQ_rep_MAG_ID', 'HQLQ_cluster']]
mrg_st2.tail(2)

# Step 3. merge mrg_st1 and mrg_st2
mrg_st3 = pd.merge(mrg_st1, mrg_st2, on='HQLQ_cluster', how='outer')
mrg_st3 = mrg_st3[['HQLQ_rep_MAG_ID','HQLQ_cluster','rep_MAG_ID', 'bin_qual','completeness', 'contamination',
       'strain_heterogeneity', 'length', 'N50', 'cluster', 'domain', 'phylum', 'class', 
       'order', 'family', 'genus', 'sp', 'bin_number_in_cluster','rep_MAG_name']]
mrg_st3.tail(2)
# Out:
#                HQLQ_rep_MAG_ID HQLQ_cluster                rep_MAG_ID  \
# 3899  L1642_Vescimonas_undS.fa       1900_2  L1642_Vescimonas_undS.fa
# 3900      L1373_WRAV01_undS.fa       1846_1      L1373_WRAV01_undS.fa
#
#      bin_qual  completeness  contamination  strain_heterogeneity   length  \
# 3899       LQ         66.77          25.86                 41.18  1729642
# 3900       MQ         70.13           0.00                  0.00  1449916
#
#         N50   cluster    domain       phylum       class            order  \
# 3899  49503  LQ-752_3  Bacteria  Bacillota_A  Clostridia  Oscillospirales
# 3900   3454  LQ-714_1  Bacteria  Bacillota_A  Clostridia  Oscillospirales
#
#                 family       genus         sp  bin_number_in_cluster  \
# 3899  Oscillospiraceae  Vescimonas  undefined                      1
# 3900   Ruminococcaceae      WRAV01  undefined                      1
#
#                rep_MAG_name
# 3899   VZTMOW_maxbin.071.fa
# 3900  VOHZH4_metabat.225.fa

# %%
# Step 4. Caclulate the number of genomes in each HQLQ_cluster
bn = mrg_st3[['rep_MAG_ID','HQLQ_cluster']].groupby('HQLQ_cluster').count()
# rename column
bn = bn.rename(columns={'rep_MAG_ID': 'rep_MAG_ID_in_HQLQcluster'})
# merge it with mrg_st3
mrg_st4 = pd.merge(mrg_st3, bn, on='HQLQ_cluster', how='outer')

mrg_st4.tail()
# Out:
#                            HQLQ_rep_MAG_ID HQLQ_cluster  \
# 3896  L1276_Vescimonas_sp900545495_undS.fa       1896_2
# 3897              L1353_Vescimonas_undS.fa       1892_4
# 3898              L1516_Vescimonas_undS.fa       1898_1
# 3899              L1642_Vescimonas_undS.fa       1900_2
# 3900                  L1373_WRAV01_undS.fa       1846_1
#
#                                 rep_MAG_ID bin_qual  completeness  \
# 3896  L1276_Vescimonas_sp900545495_undS.fa       LQ         63.95
# 3897              L1353_Vescimonas_undS.fa       LQ         85.34
# 3898              L1516_Vescimonas_undS.fa       LQ         71.87
# 3899              L1642_Vescimonas_undS.fa       LQ         66.77
# 3900                  L1373_WRAV01_undS.fa       MQ         70.13
#
#       contamination  strain_heterogeneity   length    N50    cluster  \
# 3896          18.34                 60.00  1670540  35465  LQ-755_13
# 3897          25.86                 52.94  2176363  20109   LQ-757_4
# 3898          27.59                 61.90  2283535  29276   LQ-755_6
# 3899          25.86                 41.18  1729642  49503   LQ-752_3
# 3900           0.00                  0.00  1449916   3454   LQ-714_1
#
#         domain       phylum       class            order            family  \
# 3896  Bacteria  Bacillota_A  Clostridia  Oscillospirales  Oscillospiraceae
# 3897  Bacteria  Bacillota_A  Clostridia  Oscillospirales  Oscillospiraceae
# 3898  Bacteria  Bacillota_A  Clostridia  Oscillospirales  Oscillospiraceae
# 3899  Bacteria  Bacillota_A  Clostridia  Oscillospirales  Oscillospiraceae
# 3900  Bacteria  Bacillota_A  Clostridia  Oscillospirales   Ruminococcaceae
#
#            genus                      sp  bin_number_in_cluster  \
# 3896  Vescimonas  Vescimonas sp900545495                      1
# 3897  Vescimonas               undefined                      1
# 3898  Vescimonas               undefined                      1
# 3899  Vescimonas               undefined                      1
# 3900      WRAV01               undefined                      1
#
#                    rep_MAG_name  rep_MAG_ID_in_HQLQcluster
# 3896   VL4EV4_metabat.21_sub.fa                          1
# 3897       VNNCHP_maxbin.082.fa                          1
# 3898  VTCFL1_vamb.219170_sub.fa                          1
# 3899       VZTMOW_maxbin.071.fa                          1
# 3900      VOHZH4_metabat.225.fa                          1

# %% [markdown]
# Moove to representatives MAGs from cluster

# %%
## Step 5. Select only representative MAGs
mrg_st5 = pd.merge(lst, mrg_st4, left_on='HQLQ_rep_MAG_ID', right_on='rep_MAG_ID', how='inner')
# rename column genome
mrg_st5 = mrg_st5.rename(columns={'HQLQ_rep_MAG_ID_x': 'HQLQ_rep_MAG_ID'})
# drop column centrality
mrg_st5 = mrg_st5.drop(columns=['rep_MAG_ID','HQLQ_rep_MAG_ID_y'])
mrg_st5.tail()
# Out:
#                               HQLQ_rep_MAG_ID HQLQ_cluster bin_qual  \
# 2723  L1631_Haemophilus_D_parainfluenzae_K.fa        106_1       LQ
# 2724            L1632_HGM05190_sp900759815.fa        663_1       MQ
# 2725                    L1638_UMGS872_undS.fa        380_2       LQ
# 2726                L1639_Oxalobacter_undS.fa       2063_1       LQ
# 2727                 L1642_Vescimonas_undS.fa       1900_2       LQ
#
#       completeness  contamination  strain_heterogeneity   length    N50  \
# 2723        100.00          49.29                 74.00  3007490   1894
# 2724         57.05           0.00                  0.00  1340836   8501
# 2725         50.00          24.14                  0.00  1283430  56641
# 2726         73.38          17.45                  7.14  2857230   1116
# 2727         66.77          25.86                 41.18  1729642  49503
#
#         cluster    domain          phylum                class  \
# 2723   LQ-457_3  Bacteria  Pseudomonadota  Gammaproteobacteria
# 2724   LQ-501_1  Bacteria    Bacteroidota          Bacteroidia
# 2725   LQ-185_4  Bacteria       Bacillota              Bacilli
# 2726  LQ-1022_2  Bacteria  Pseudomonadota  Gammaproteobacteria
# 2727   LQ-752_3  Bacteria     Bacillota_A           Clostridia
#
#                    order            family          genus  \
# 2723  Enterobacterales_A   Pasteurellaceae  Haemophilus_D
# 2724       Bacteroidales    Muribaculaceae       HGM05190
# 2725                RF39            UBA660        UMGS872
# 2726     Burkholderiales  Burkholderiaceae    Oxalobacter
# 2727     Oscillospirales  Oscillospiraceae     Vescimonas
#
#                                   sp  bin_number_in_cluster  \
# 2723  Haemophilus_D parainfluenzae_K                      1
# 2724            HGM05190 sp900759815                      1
# 2725                       undefined                      1
# 2726                       undefined                      1
# 2727                       undefined                      1
#
#                   rep_MAG_name  rep_MAG_ID_in_HQLQcluster
# 2723      VZGZLV_maxbin.027.fa                          1
# 2724     VZHO9I_vamb.250220.fa                          1
# 2725  VZR2LZ_maxbin.071_sub.fa                          1
# 2726      VZR2LZ_maxbin.165.fa                          1
# 2727      VZTMOW_maxbin.071.fa                          1

# %% [markdown]
# ## Save the files

# %%
# SAVE FINAL TABLE with all MAGs came from HQ an LQ clustering 
#mrg_st4.to_excel('results/together_HQLQcl_all_MAGs_all_info.xlsx', index=False)

# %%
# SAVE FINAL TABLE with only HQLQ_rep_MAGs came from HQ an LQ clustering 
mrg_st5.to_excel('results/together_HQLQcl_representative_MAGs_all_info.xlsx', index=False)

# %% [markdown]
# ## Make a table with all possible bins!

# %%
hq_all = pd.read_excel('results/HQcl_all_bins_all_info.xlsx')
hq_all = hq_all[['bin_name', 'bin_qual', 'completeness', 'contamination','domain', 'phylum', 'class', 
                 'order', 'family', 'genus', 'sp','cluster', 'bin_number_in_cluster','rep_MAG_ID',
                 'strain_heterogeneity', 'length']]

lq_all = pd.read_excel('results/LQcl_all_bins_all_info.xlsx')
lq_all = lq_all[['bin_name', 'bin_qual', 'completeness', 'contamination','domain', 'phylum', 'class', 
                 'order', 'family', 'genus', 'sp','cluster', 'bin_number_in_cluster','rep_MAG_ID',
                 'strain_heterogeneity', 'length']]

bin_all = pd.concat([hq_all, lq_all]).reset_index(drop=True, inplace=True)

# %%
bin_all.head(2)
# Out:
#                 bin_name bin_qual  completeness  contamination    domain  \
# 0       V0404P_175861.fa       MQ         84.48            0.0  Bacteria
# 1  V1T1XL_vamb.223401.fa       HQ         91.38            0.0  Bacteria
#
#          phylum        class          order          family     genus  \
# 0  Bacteroidota  Bacteroidia  Bacteroidales  Muribaculaceae  Limisoma
# 1  Bacteroidota  Bacteroidia  Bacteroidales  Muribaculaceae  Limisoma
#
#                      sp   cluster  bin_number_in_cluster  \
# 0  Limisoma sp000437795  HQ-613_1                    580
# 1  Limisoma sp000437795  HQ-613_1                    580
#
#                       rep_MAG_ID  strain_heterogeneity   length
# 0  H0011_Limisoma_sp000437795.fa                   0.0  2184033
# 1  H0011_Limisoma_sp000437795.fa                   0.0  2306061

# %%
ncl_bin = pd.read_excel('results/LQ_bins_without_cl_b2b3.xlsx')
#ncl_bin = ncl_bin.rename(columns={'rep_MAG_name': 'bin_name'})
ncl_bin.head(2)
# Out:
#                bin_name   domain             phylum            class  \
# 0  V04YHL_vamb.15881.fa  Archaea  Methanobacteriota  Methanobacteria
# 1  V1BPF7_metabat.81.fa  Archaea  Methanobacteriota  Methanobacteria
#
#                 order               family                 genus  \
# 0  Methanobacteriales  Methanobacteriaceae  Methanobrevibacter_A
# 1  Methanobacteriales  Methanobacteriaceae  Methanobrevibacter_A
#
#                              sp
# 0  Methanobrevibacter_A smithii
# 1  Methanobrevibacter_A smithii

# %%
# Merge df1 and df2 to fill undefined values
merged_df = bin_all.merge(ncl_bin, on='bin_name', suffixes=('', '_df2'), how='left')

# Replace undefined values in df1 with values from df2
columns_to_fill = ['domain', 'phylum', 'class','order', 'family', 'genus', 'sp']
for column in columns_to_fill:
    undefined_mask = merged_df[column] == 'undefined'
    merged_df.loc[undefined_mask, column] = merged_df.loc[undefined_mask, f'{column}_df2']

# Drop the extra columns from df2
merged_df.drop(columns=[f'{column}_df2' for column in columns_to_fill], inplace=True)

merged_df.tail(2)
# Out:
#                         bin_name bin_qual  completeness  contamination domain  \
# 84760  V5TGN9_vamb.150645_sub.fa       LQ         100.0         120.69    NaN
# 84761        V68KXR_55755_sub.fa       LQ         100.0         125.75    NaN
#
#       phylum class order family genus   sp    cluster  bin_number_in_cluster  \
# 84760    NaN   NaN   NaN    NaN   NaN  NaN  undefined                   5955
# 84761    NaN   NaN   NaN    NaN   NaN  NaN  undefined                   5955
#
#       rep_MAG_ID  strain_heterogeneity    length
# 84760        NaN                 35.65   7065269
# 84761        NaN                 26.45  10934240

# %%
# SAVE FINAL TABLE with all MAGs came from HQ an LQ clustering 
merged_df.to_excel('results/together_all_MAGs_all_info.xlsx', index=False)
